# %% [markdown]
# <a href="https://colab.research.google.com/github/dayoungcho/cau/blob/main/ch2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### task1

# %%
import numpy as np
import pandas as pd

# %%
introduction= {
        'Name': ['좌대현','김가은','윤효정','조다영','김휘중'],
        'Hobby': ['운동하기', '음악듣기', '축구하기', '영화보기', '축구보기'],
        'Nationality': ['Korea', 'Korea', 'Korea', 'Korea', 'Korea'],
        'Major': ['응용통계', '응용통계', '응용통계', '응용통계', '경영'],
        'random_number': [304, 1039, 102, 399, 319]}

# %%
df = pd.DataFrame(introduction)
df
# Out:
#   Name Hobby Nationality Major  random_number
# 0  좌대현  운동하기       Korea  응용통계            304
# 1  김가은  음악듣기       Korea  응용통계           1039
# 2  윤효정  축구하기       Korea  응용통계            102
# 3  조다영  영화보기       Korea  응용통계            399
# 4  김휘중  축구보기       Korea    경영            319

# %% [markdown]
# ### task2

# %%
df2 = pd.DataFrame(introduction,
                   index = [np.arange(5)+1])
df2
# Out:
#   Name Hobby Nationality Major  random_number
# 1  좌대현  운동하기       Korea  응용통계            304
# 2  김가은  음악듣기       Korea  응용통계           1039
# 3  윤효정  축구하기       Korea  응용통계            102
# 4  조다영  영화보기       Korea  응용통계            399
# 5  김휘중  축구보기       Korea    경영            319

# %%
df2.to_csv('ch2.csv')

# %%
pd.read_csv('ch2.csv')
# Out:
#    Unnamed: 0 Name Hobby Nationality Major  random number
# 0           1  좌대현  운동하기       Korea  응용통계            304
# 1           2  김가은  음악듣기       Korea  응용통계           1039
# 2           3  윤효정  축구하기       Korea  응용통계            102
# 3           4  조다영  영화보기       Korea  응용통계            399
# 4           5  김휘중  축구보기       Korea    경영            319

# %% [markdown]
# ### optional task(summarizing methods)

# %%
df2.shape
# Out:
# (5, 5)

# %%
df2.columns
# Out:
# Index(['Name', 'Hobby', 'Nationality', 'Major', 'random number'], dtype='object')

# %%
df2.dtypes
# Out:
# Name             object
# Hobby            object
# Nationality      object
# Major            object
# random number     int64
# dtype: object

# %%
df2['random_number'].describe(percentiles=[0.05, 0.95])
# Out:
# count       5.000000
# mean      432.600000
# std       356.226473
# min       102.000000
# 5%        142.400000
# 50%       319.000000
# 95%       911.000000
# max      1039.000000
# Name: random number, dtype: float64

# %%
df2.describe(include=np.object)
# Out:
# <ipython-input-42-ccbc6cff3f19>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df2.describe(include=np.object)
#        Name Hobby Nationality Major
# count     5     5           5     5
# unique    5     5           1     2
# top     좌대현  운동하기       Korea  응용통계
# freq      1     1           5     4

# %%
df2.Major.value_counts()
# Out:
# 응용통계    4
# 경영      1
# Name: Major, dtype: int64

# %%
print(df2.random_number.max())
print(df2.random_number.var())
# Out:
# 1039
# 126897.30000000002

# %% [markdown]
# ### 디렉토리 설정

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import sys
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Colab Notebooks/AI를 위한 머신러닝/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02
# Out:
# /content/drive/MyDrive/Colab Notebooks/AI를 위한 머신러닝/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
os.listdir()
# Out:
# ['3-making_dataframes_from_api_requests.ipynb',
#  '4-inspecting_dataframes.ipynb',
#  '5-subsetting_data.ipynb',
#  '6-adding_and_removing_data.ipynb',
#  'README.md',
#  'data',
#  '1-pandas_data_structures.ipynb',
#  'output.csv',
#  '2-creating_dataframes.ipynb']

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/AI를 위한 머신러닝/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02'

# %%
ls
# Out:
# 1-pandas_data_structures.ipynb               6-adding_and_removing_data.ipynb
# 2-creating_dataframes.ipynb                  data/
# 3-making_dataframes_from_api_requests.ipynb  output.csv
# 4-inspecting_dataframes.ipynb                README.md
# 5-subsetting_data.ipynb
