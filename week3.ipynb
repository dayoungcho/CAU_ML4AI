# %% [markdown]
# <a href="https://colab.research.google.com/github/dayoungcho/cau/blob/main/week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import sys
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Colab Notebooks/AI를 위한 머신러닝/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02
# Out:
# /content/drive/MyDrive/Colab Notebooks/AI를 위한 머신러닝/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
import pandas as pd

# %%
df = pd.read_csv('data/earthquakes.csv')
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
# ...

# %% [markdown]
# ## Task1

# %% [markdown]
# ### Try loc and ilocfunction

# %%
df.loc[3:11,['mag','magType','type']]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake
# 11  2.77      md  earthquake

# %% [markdown]
# ### Try to find items of location Arizona

# %%
df[df.place.str.contains('Arizona')]
# Out:
#      alert  cdi      code                                             detail  \
# 1062   NaN  NaN  60300227  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3965   NaN  NaN  60298572  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...    status  \
# 1062  0.1666   NaN  163.0  ,uu60300227,  1.23      ml  ...  reviewed
# 3965  0.1577   NaN  211.0  ,uu60298572,  0.94      md  ...  reviewed
#
#                time                                      title tsunami  \
# 1062  1539133978610  M 1.2 - 7km SSW of Colorado City, Arizona       0
# 3965  1538383710020  M 0.9 - 7km WSW of Colorado City, Arizona       0
#
#             type                         types     tz        updated  \
# 1062  earthquake  ,geoserve,origin,phase-data, -420.0  1539196068710
# 3965  earthquake  ,geoserve,origin,phase-data, -420.0  1538516934720
#
#                                                     url parsed_place
# ...

# %%
# 변수 생성
df.place.str.extract(r', (.*$)')[0].sort_values().unique()
# Out:
# array(['Afghanistan', 'Alaska', 'Argentina', 'Arizona', 'Arkansas',
#        'Australia', 'Azerbaijan', 'B.C., MX', 'Barbuda', 'Bolivia',
#        'Bonaire, Saint Eustatius and Saba ', 'British Virgin Islands',
#        'Burma', 'CA', 'California', 'Canada', 'Chile', 'China',
#        'Christmas Island', 'Colombia', 'Colorado', 'Costa Rica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Ecuador region',
#        'El Salvador', 'Fiji', 'Greece', 'Greenland', 'Guam', 'Guatemala',
#        'Haiti', 'Hawaii', 'Honduras', 'Idaho', 'Illinois', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Italy', 'Jamaica', 'Japan', 'Kansas',
#        'Kentucky', 'Kyrgyzstan', 'Martinique', 'Mauritius', 'Mayotte',
#        'Mexico', 'Missouri', 'Montana', 'NV', 'Nevada', 'New Caledonia',
#        'New Hampshire', 'New Mexico', 'New Zealand', 'Nicaragua',
#        'North Carolina', 'Northern Mariana Islands', 'Oklahoma', 'Oregon',
#        'Pakistan', 'Papua New Guinea', 'Peru', 'Philippines',
# ...

# %%
df['parsed_place'] = df.place.str.replace(
    r'.* of ', '', regex=True # remove anything saying <something> of <something>
).str.replace(
    'the ', '' # remove "the "
).str.replace(
    r'CA$', 'California', regex=True # fix California
).str.replace(
    r'NV$', 'Nevada', regex=True # fix Nevada
).str.replace(
    r'MX$', 'Mexico', regex=True # fix Mexico
).str.replace(
    r' region$', '', regex=True # chop off endings with " region"
).str.replace(
    'northern ', '' # remove "northern "
).str.replace(
    'Fiji Islands', 'Fiji' # line up the Fiji places
).str.replace(
    r'^.*, ', '', regex=True # remove anything else extraneous from the beginning
).str.strip() # remove any extra spaces

# %%
df.parsed_place.sort_values().unique()
# Out:
# array(['Afghanistan', 'Alaska', 'Argentina', 'Arizona', 'Arkansas',
#        'Ascension Island', 'Australia', 'Azerbaijan', 'Balleny Islands',
#        'Barbuda', 'Bolivia', 'British Virgin Islands', 'Burma',
#        'California', 'Canada', 'Carlsberg Ridge',
#        'Central East Pacific Rise', 'Central Mid-Atlantic Ridge', 'Chile',
#        'China', 'Christmas Island', 'Colombia', 'Colorado', 'Costa Rica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'El Salvador',
#        'Fiji', 'Greece', 'Greenland', 'Guam', 'Guatemala', 'Haiti',
#        'Hawaii', 'Honduras', 'Idaho', 'Illinois', 'India',
#        'Indian Ocean Triple Junction', 'Indonesia', 'Iran', 'Iraq',
#        'Italy', 'Jamaica', 'Japan', 'Kansas', 'Kentucky',
#        'Kermadec Islands', 'Kuril Islands', 'Kyrgyzstan', 'Martinique',
#        'Mauritius', 'Mayotte', 'Mexico', 'Mid-Indian Ridge', 'Missouri',
#        'Montana', 'Nevada', 'New Caledonia', 'New Hampshire',
# ...

# %%
df[df.parsed_place=='Arizona']
# Out:
#      alert  cdi      code                                             detail  \
# 1062   NaN  NaN  60300227  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3965   NaN  NaN  60298572  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...    status  \
# 1062  0.1666   NaN  163.0  ,uu60300227,  1.23      ml  ...  reviewed
# 3965  0.1577   NaN  211.0  ,uu60298572,  0.94      md  ...  reviewed
#
#                time                                      title tsunami  \
# 1062  1539133978610  M 1.2 - 7km SSW of Colorado City, Arizona       0
# 3965  1538383710020  M 0.9 - 7km WSW of Colorado City, Arizona       0
#
#             type                         types     tz        updated  \
# 1062  earthquake  ,geoserve,origin,phase-data, -420.0  1539196068710
# 3965  earthquake  ,geoserve,origin,phase-data, -420.0  1538516934720
#
#                                                     url parsed_place
# ...

# %% [markdown]
# ### 10 largest items of mag variable

# %%
df1 = df.sort_values('mag',ascending=False)

# %%
df1[:10][['mag','magType','type','parsed_place']]
# Out:
#       mag magType        type            parsed_place
# 5263  7.5     mww  earthquake               Indonesia
# 837   7.0     mww  earthquake        Papua New Guinea
# 4363  6.7     mww  earthquake                    Fiji
# 118   6.7     mww  earthquake                  Russia
# 799   6.5     mww  earthquake                  Russia
# 816   6.2     mww  earthquake        Papua New Guinea
# 838   6.1      mb  earthquake        Papua New Guinea
# 5323  6.1     mww  earthquake               Indonesia
# 9211  6.0     mww  earthquake  Southwest Indian Ridge
# 862   6.0     mww  earthquake               Indonesia

# %% [markdown]
# ## Task2

# %% [markdown]
# ### delete alert variable

# %%
del df['alert']
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag', 'magType',
#        'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %% [markdown]
# ###  pop mag and magType variables

# %%
mag = df.pop('mag')
magType = df.pop('magType')

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mmi',
#        'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %% [markdown]
# ### Concatenate mag and magType variables

# %%
df3 = pd.concat([mag, magType],axis=1)
df3
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]
